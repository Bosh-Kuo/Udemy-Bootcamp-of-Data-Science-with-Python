# %% [markdown]
# ## Generate a sample of the Chi-Square distribution with 3 degrees of freedom and a 5 x 5 shape;

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import random

arr1 = random.chisquare(df = 3, size = (5, 5))
print(arr1)
# Out:
# [[ 0.46519283  1.25930427 11.42090184  6.60072156  7.78682462]
#  [ 7.02294316  1.14630669  3.10420549  3.49976293  3.86253232]
#  [ 2.09631426  6.72918473  3.23359968  3.29565919  1.2840663 ]
#  [ 1.73579221  2.69622458  9.35776326  3.48055698  4.64792247]
#  [ 2.37590227  3.98211652  0.7561107   6.03132575  4.78984604]]

# %% [markdown]
# ## Generate a sample of the Chi-Square distribution with 2 degrees of freedom and size 2,000 and plot a graph to visualize the generated probability distribution;

# %%
arr2 = random.chisquare(df = 2, size = 2_000)
plt.figure(figsize = (10, 8))
sns.histplot(arr2, kde = True, color = 'red');

# %% [markdown]
# ## Generate a sample of an Exponential distribution with scale 5 and 2 x 2 shape.

# %%
arr3 = random.exponential(scale = 5, size = (2, 2))
