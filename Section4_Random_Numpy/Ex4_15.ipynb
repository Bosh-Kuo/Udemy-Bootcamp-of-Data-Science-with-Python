# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

array = np.random.poisson(lam = 3, size = 10_000)
series = pd.Series(array, name = 'Poisson')

sns.histplot(series, kde = True)
plt.show()

# %%
series
# Out:
# 0       5
# 1       1
# 2       3
# 3       3
# 4       0
#        ..
# 9995    1
# 9996    5
# 9997    1
# 9998    3
# 9999    2
# Name: Poisson, Length: 10000, dtype: int64
